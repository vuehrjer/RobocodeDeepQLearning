# %%
robocodePath = 'D:/FHTech/Sem2/ARL/Robocode/INSTALL/'
configFilePath = r'D:\FHTech\Sem2\ARL\Repo\RobocodeDeepQLearning\out\production\RobocodeDeepQLearning\ARL\Rl_nn.data\config.txt'
generations=300
import subprocess
for x in range(generations):
    p1 = subprocess.Popen('java -Xmx512M -Dsun.io.useCanonCaches=false -DPARALLEL=true -cp libs/robocode.jar robocode.Robocode -battle ./battles/NNTrainCrazy.battle -tps 1000000 -nodisplay', cwd = robocodePath)
    p1.wait()
    #overwrite config to 0 0
    f = open(configFilePath, "w")
    f.write("0\n0\n")
    f.close()
    p2 = subprocess.Popen('java -Xmx512M -Dsun.io.useCanonCaches=false -DPARALLEL=true -cp libs/robocode.jar robocode.Robocode -battle ./battles/NNTrain.battle -tps 1000000 -nodisplay', cwd = robocodePath)
    p2.wait()
    print("gen: " + str(x+1) + " of " + str(generations) + " done")
# Out:
# gen: 1 of 300 done
# gen: 2 of 300 done
# gen: 3 of 300 done
# gen: 4 of 300 done
# gen: 5 of 300 done
# gen: 6 of 300 done
# gen: 7 of 300 done
# gen: 8 of 300 done
# gen: 9 of 300 done
# gen: 10 of 300 done
# gen: 11 of 300 done
# gen: 12 of 300 done
# gen: 13 of 300 done
# gen: 14 of 300 done
# gen: 15 of 300 done
# gen: 16 of 300 done
# gen: 17 of 300 done
# gen: 18 of 300 done
# gen: 19 of 300 done
# gen: 20 of 300 done
# gen: 21 of 300 done
# gen: 22 of 300 done
# gen: 23 of 300 done
# gen: 24 of 300 done
# gen: 25 of 300 done
# gen: 26 of 300 done
# gen: 27 of 300 done
# gen: 28 of 300 done
# gen: 29 of 300 done
# gen: 30 of 300 done
# gen: 31 of 300 done
# gen: 32 of 300 done
# gen: 33 of 300 done
# gen: 34 of 300 done
# gen: 35 of 300 done
# gen: 36 of 300 done
# gen: 37 of 300 done
# gen: 38 of 300 done
# gen: 39 of 300 done
# gen: 40 of 300 done
# gen: 41 of 300 done
# gen: 42 of 300 done
# gen: 43 of 300 done
# gen: 44 of 300 done
# gen: 45 of 300 done
# ...
